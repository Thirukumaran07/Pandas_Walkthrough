# %%
import pandas as pd

# %%
df=pd.read_csv("/Users/apple/Downloads/extracted_data.csv")

# %%
df
# Out:
#     Sales  Units  Transactions  Gross Profits  Customers Promotions(Yes/No)  \
# 0   701.0     49            38             37         99                Yes
# 1   807.0     73            14             81         81                Yes
# 2   743.0     23            75             38         40                Yes
# 3   347.0     85            82             74         32                Yes
# 4   275.0    100            10             83         43                Yes
# 5   397.0     35            38             68         28                 No
# 6   744.0     14            64             41         73                Yes
# 7   519.0     47            78             17         11                 No
# 8   822.0     11            33             87         89                 No
# 9   138.0     46            97             14         61                 No
# 10  652.0     92            74             67         97                Yes
# ...

# %%
### mean

# %%
df['Units'].mean()
# Out:
# np.float64(84.32142857142857)

# %%
df['Units'].sum()/df.shape[0]
# Out:
# np.float64(84.32142857142857)

# %%
### median

# %%
df['Units'].median()
# Out:
# np.float64(54.0)

# %%
df[['Units','Sales','Transactions']].median()
# Out:
# Units            54.0
# Sales           453.0
# Transactions     52.0
# dtype: float64

# %%
### mode

# %%
df['Units'].mode()
# Out:
# 0    47
# 1    72
# Name: Units, dtype: int64

# %%
df['Customers'].mode()
# Out:
# 0    11
# 1    32
# 2    61
# Name: Customers, dtype: int64

# %%
### variance standard deviation

# %%
df['Units'].std()
# Out:
# np.float64(172.22015487750483)

# %%
df['Units'].var()
# Out:
# np.float64(29659.781746031746)

# %%
### Quartiles, InterQuartiles

# %%
df['Units'].quantile(0.25)
# Out:
# np.float64(31.5)

# %%
df['Units'].quantile(0.50)
# Out:
# np.float64(54.0)

# %%
df['Units'].quantile(0.75)
# Out:
# np.float64(74.0)

# %%
df['Units'].quantile(1)
# Out:
# np.float64(953.0)

# %%
df['Units'].quantile(0.75)-df['Units'].quantile(0.25)
# Out:
# np.float64(42.5)
