# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = sns.load_dataset("mpg")

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
df.drop("mpg",axis=1,inplace=True)

# %%
df.head()
# Out:
#    cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 0          8         307.0       130.0    3504          12.0          70
# 1          8         350.0       165.0    3693          11.5          70
# 2          8         318.0       150.0    3436          11.0          70
# 3          8         304.0       150.0    3433          12.0          70
# 4          8         302.0       140.0    3449          10.5          70
#
#   origin                       name
# 0    usa  chevrolet chevelle malibu
# 1    usa          buick skylark 320
# 2    usa         plymouth satellite
# 3    usa              amc rebel sst
# 4    usa                ford torino

# %%
df.drop([0,1],axis=0,inplace=True)

# %%
df.head()
# Out:
#    cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 2          8         318.0       150.0    3436          11.0          70
# 3          8         304.0       150.0    3433          12.0          70
# 4          8         302.0       140.0    3449          10.5          70
# 5          8         429.0       198.0    4341          10.0          70
# 6          8         454.0       220.0    4354           9.0          70
#
#   origin                name
# 2    usa  plymouth satellite
# 3    usa       amc rebel sst
# 4    usa         ford torino
# 5    usa    ford galaxie 500
# 6    usa    chevrolet impala

# %%
df.head()
# Out:
#    cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 2          8         318.0       150.0    3436          11.0          70
# 3          8         304.0       150.0    3433          12.0          70
# 4          8         302.0       140.0    3449          10.5          70
# 5          8         429.0       198.0    4341          10.0          70
# 6          8         454.0       220.0    4354           9.0          70
#
#   origin                name
# 2    usa  plymouth satellite
# 3    usa       amc rebel sst
# 4    usa         ford torino
# 5    usa    ford galaxie 500
# 6    usa    chevrolet impala

# %%
df.rename(columns={'cylinders':"cyl"},inplace=True)

# %%
df.head()
# Out:
#    cyl  displacement  horsepower  weight  acceleration  model_year origin  \
# 2    8         318.0       150.0    3436          11.0          70    usa
# 3    8         304.0       150.0    3433          12.0          70    usa
# 4    8         302.0       140.0    3449          10.5          70    usa
# 5    8         429.0       198.0    4341          10.0          70    usa
# 6    8         454.0       220.0    4354           9.0          70    usa
#
#                  name
# 2  plymouth satellite
# 3       amc rebel sst
# 4         ford torino
# 5    ford galaxie 500
# 6    chevrolet impala

# %%
df.rename(index={2:"test"}, inplace=True)

# %%
df.head()
# Out:
#       cyl  displacement  horsepower  weight  acceleration  model_year origin  \
# test    8         318.0       150.0    3436          11.0          70    usa
# 3       8         304.0       150.0    3433          12.0          70    usa
# 4       8         302.0       140.0    3449          10.5          70    usa
# 5       8         429.0       198.0    4341          10.0          70    usa
# 6       8         454.0       220.0    4354           9.0          70    usa
#
#                     name
# test  plymouth satellite
# 3          amc rebel sst
# 4            ford torino
# 5       ford galaxie 500
# 6       chevrolet impala
