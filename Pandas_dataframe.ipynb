# %%
import pandas as pd

# %%
pd.DataFrame([[300,15,'Yes'],[400,30,'No'],[500,40,'Yes']])
# Out:
#      0   1    2
# 0  300  15  Yes
# 1  400  30   No
# 2  500  40  Yes

# %%
pd.DataFrame([[300,15,'Yes'],[400,30,'No'],[500,40,'Yes']],columns=['$Sales','Units','Promotions'],index = ['Jan','Feb','Mar'])
# Out:
#      $Sales  Units Promotions
# Jan     300     15        Yes
# Feb     400     30         No
# Mar     500     40        Yes

# %%
### implementing dataframws using list

# %%
d = {'Jan':[200,300],'Feb':[300,400]}

# %%
d
# Out:
# {'Jan': [200, 300], 'Feb': [300, 400]}

# %%
pd.DataFrame(d,index = ['Sales','Customers'])
# Out:
#            Jan  Feb
# Sales      200  300
# Customers  300  400

# %%
### creating dataframe using numpy

# %%
import numpy as np

# %%
np.random.randint(0,9,(3,3))
# Out:
# array([[3, 4, 1],
#        [2, 4, 5],
#        [6, 5, 0]])

# %%
data = np.random.randint(10,20,(3,3))

# %%
data
# Out:
# array([[18, 11, 12],
#        [16, 14, 10],
#        [14, 17, 11]])

# %%
pd.DataFrame(data)
# Out:
#     0   1   2
# 0  18  11  12
# 1  16  14  10
# 2  14  17  11

# %%
pd.DataFrame(data,index=['A','B','C'],columns=['X','Y','Z'])
# Out:
#     X   Y   Z
# A  18  11  12
# B  16  14  10
# C  14  17  11
