# %%
import pandas as pd

# %%
### Series

# %%
pd.Series([12,34,56])
# Out:
# 0    12
# 1    34
# 2    56
# dtype: int64

# %%
pd.Series([12,34,56],index=['jan','feb','mar'])
# Out:
# jan    12
# feb    34
# mar    56
# dtype: int64

# %%
dt = {'jan':200,'feb':400,'mar':600}

# %%
pd.Series(dt)
# Out:
# jan    200
# feb    400
# mar    600
# dtype: int64

# %%
var = pd.Series(dt)
var
# Out:
# jan    200
# feb    400
# mar    600
# dtype: int64

# %%
var['jan']
# Out:
# np.int64(200)

# %%
"jan" in var ### in to check keyss
# Out:
# True

# %%
var*2 ### all mathematical are able to perform
# Out:
# jan     400
# feb     800
# mar    1200
# dtype: int64

# %%
var**2
# Out:
# jan     40000
# feb    160000
# mar    360000
# dtype: int64

# %%
sales = pd.Series([43,65,23,76,23,64,45,21,33,78,87,50])

# %%
sales
# Out:
# 0     43
# 1     65
# 2     23
# 3     76
# 4     23
# 5     64
# 6     45
# 7     21
# 8     33
# 9     78
# 10    87
# 11    50
# dtype: int64

# %%
sales.index = ['j','f','m','a','m','j','ju','au','s','o','n','d']

# %%
sales
# Out:
# j     43
# f     65
# m     23
# a     76
# m     23
# j     64
# ju    45
# au    21
# s     33
# o     78
# n     87
# d     50
# dtype: int64

# %%
sales.head()
# Out:
# j    43
# f    65
# m    23
# a    76
# m    23
# dtype: int64

# %%
sales.head(3)
# Out:
# j    43
# f    65
# m    23
# dtype: int64

# %%
sales.tail()
# Out:
# au    21
# s     33
# o     78
# n     87
# d     50
# dtype: int64

# %%
sales.tail(3)
# Out:
# o    78
# n    87
# d    50
# dtype: int64

# %%
sales.min()
# Out:
# np.int64(21)

# %%
sales.max()
# Out:
# np.int64(87)

# %%
sales.sum()
# Out:
# np.int64(608)

# %%
sales.mean()
# Out:
# np.float64(50.666666666666664)

# %%
sales.std()
# Out:
# np.float64(23.172606607149245)

# %%
sales.var()
# Out:
# np.float64(536.9696969696969)

# %%
sales.unique()
# Out:
# array([43, 65, 23, 76, 64, 45, 21, 33, 78, 87, 50])

# %%
sales.nunique()
# Out:
# 11

# %%
sales.value_counts()
# Out:
# 23    2
# 43    1
# 65    1
# 76    1
# 64    1
# 45    1
# 21    1
# 33    1
# 78    1
# 87    1
# 50    1
# Name: count, dtype: int64

# %%
### Data Frame
