# %%
import pandas as pd

# %%
pd.read_csv("/Users/apple/Downloads/extracted_data.csv")
# Out:
#     Sales  Units  Transactions  Gross Profits  Customers Promotions(Yes/No)  \
# 0   701.0     49            38             37         99                Yes
# 1   807.0     73            14             81         81                Yes
# 2   743.0     23            75             38         40                Yes
# 3   347.0     85            82             74         32                Yes
# 4   275.0    100            10             83         43                Yes
# 5   397.0     35            38             68         28                 No
# 6   744.0     14            64             41         73                Yes
# 7   519.0     47            78             17         11                 No
# 8   822.0     11            33             87         89                 No
# 9   138.0     46            97             14         61                 No
# 10  652.0     92            74             67         97                Yes
# ...

# %%
sales_df = pd.read_csv("/Users/apple/Downloads/extracted_data.csv")

# %%
sales_df
# Out:
#     Sales  Units  Transactions  Gross Profits  Customers Promotions(Yes/No)  \
# 0   701.0     49            38             37         99                Yes
# 1   807.0     73            14             81         81                Yes
# 2   743.0     23            75             38         40                Yes
# 3   347.0     85            82             74         32                Yes
# 4   275.0    100            10             83         43                Yes
# 5   397.0     35            38             68         28                 No
# 6   744.0     14            64             41         73                Yes
# 7   519.0     47            78             17         11                 No
# 8   822.0     11            33             87         89                 No
# 9   138.0     46            97             14         61                 No
# 10  652.0     92            74             67         97                Yes
# ...

# %%
### columns rows and inbuilt functions that subsetting data

# %%
sales_df.head()
# Out:
#    Sales  Units  Transactions  Gross Profits  Customers Promotions(Yes/No)  \
# 0  701.0     49            38             37         99                Yes
# 1  807.0     73            14             81         81                Yes
# 2  743.0     23            75             38         40                Yes
# 3  347.0     85            82             74         32                Yes
# 4  275.0    100            10             83         43                Yes
#
#     Location   Days
# 0  Bangalore  Day 1
# 1  Bangalore  Day 2
# 2  Bangalore  Day 3
# 3  Bangalore  Day 4
# 4  Bangalore  Day 5

# %%
sales_df.tail()
# Out:
#     Sales  Units  Transactions  Gross Profits  Customers Promotions(Yes/No)  \
# 23  105.0     70            16             84         18                Yes
# 24  236.0     34            87             54         41                Yes
# 25  402.0     24            84             85         67                Yes
# 26  543.0     77            37             68         11                 No
# 27  622.0     13            73             25         24                Yes
#
#    Location   Days
# 23   Mumbai  Day 3
# 24   Mumbai  Day 4
# 25   Mumbai  Day 5
# 26   Mumbai  Day 6
# 27   Mumbai  Day 7

# %%
sales_df['Sales']
# Out:
# 0     701.0
# 1     807.0
# 2     743.0
# 3     347.0
# 4     275.0
# 5     397.0
# 6     744.0
# 7     519.0
# 8     822.0
# 9     138.0
# 10    652.0
# 11    410.0
# 12    879.0
# 13    255.0
# 14    122.0
# 15    453.0
# 16    746.0
# 17    962.0
# 18    436.0
# 19    132.0
# 20    131.0
# 21    631.0
# 22      NaN
# 23    105.0
# 24    236.0
# 25    402.0
# 26    543.0
# 27    622.0
# Name: Sales, dtype: float64

# %%
sales_df['Location'].head()
# Out:
# 0    Bangalore
# 1    Bangalore
# 2    Bangalore
# 3    Bangalore
# 4    Bangalore
# Name: Location, dtype: str

# %%
sales_df[['Location','Units','Customers']]
# Out:
#      Location  Units  Customers
# 0   Bangalore     49         99
# 1   Bangalore     73         81
# 2   Bangalore     23         40
# 3   Bangalore     85         32
# 4   Bangalore    100         43
# 5   Bangalore     35         28
# 6   Bangalore     14         73
# 7     Chennai     47         11
# 8     Chennai     11         89
# 9     Chennai     46         61
# 10    Chennai     92         97
# 11    Chennai     56         66
# 12    Chennai     79         21
# 13    Chennai     72         61
# 14  Hyderabad     64         78
# 15  Hyderabad     58         53
# 16  Hyderabad     72         46
# 17  Hyderabad     20         57
# 18  Hyderabad     47         70
# 19  Hyderabad     52         90
# 20  Hyderabad     15         16
# 21     Mumbai     80         75
# 22     Mumbai    953         32
# 23     Mumbai     70         18
# 24     Mumbai     34         41
# 25     Mumbai     24         67
# 26     Mumbai     77         11
# 27     Mumbai     13         24

# %%
sales_df[['Location','Units','Customers']].head()
# Out:
#     Location  Units  Customers
# 0  Bangalore     49         99
# 1  Bangalore     73         81
# 2  Bangalore     23         40
# 3  Bangalore     85         32
# 4  Bangalore    100         43

# %%
sales_df[0:8]
# Out:
#    Sales  Units  Transactions  Gross Profits  Customers Promotions(Yes/No)  \
# 0  701.0     49            38             37         99                Yes
# 1  807.0     73            14             81         81                Yes
# 2  743.0     23            75             38         40                Yes
# 3  347.0     85            82             74         32                Yes
# 4  275.0    100            10             83         43                Yes
# 5  397.0     35            38             68         28                 No
# 6  744.0     14            64             41         73                Yes
# 7  519.0     47            78             17         11                 No
#
#     Location   Days
# 0  Bangalore  Day 1
# 1  Bangalore  Day 2
# 2  Bangalore  Day 3
# 3  Bangalore  Day 4
# 4  Bangalore  Day 5
# 5  Bangalore  Day 6
# 6  Bangalore  Day 7
# 7    Chennai  Day 1

# %%
sales_df[10:15]
# Out:
#     Sales  Units  Transactions  Gross Profits  Customers Promotions(Yes/No)  \
# 10  652.0     92            74             67         97                Yes
# 11  410.0     56            50             30         66                Yes
# 12  879.0     79            18             33         21                 No
# 13  255.0     72            52             37         61                Yes
# 14  122.0     64            27             28         78                 No
#
#      Location   Days
# 10    Chennai  Day 4
# 11    Chennai  Day 5
# 12    Chennai  Day 6
# 13    Chennai  Day 7
# 14  Hyderabad  Day 1

# %%
### general purpose inbuilt function

# %%
sales_df.columns
# Out:
# Index(['Sales', 'Units', 'Transactions', 'Gross Profits', 'Customers',
#        'Promotions(Yes/No)', 'Location', 'Days'],
#       dtype='str')

# %%
sales_df.index
# Out:
# RangeIndex(start=0, stop=28, step=1)

# %%
sales_df['Sales'].min()
# Out:
# np.float64(105.0)

# %%
sales_df[['Sales','Units']].min()
# Out:
# Sales    105.0
# Units     11.0
# dtype: float64

# %%
sales_df[['Sales','Units']].max()
# Out:
# Sales    962.0
# Units    953.0
# dtype: float64

# %%
sales_df[['Sales','Units']].sum()
# Out:
# Sales    13210.0
# Units     2361.0
# dtype: float64

# %%
sales_df['Sales'].sum()
# Out:
# np.float64(13210.0)

# %%
sales_df['Sales'].mean()
# Out:
# np.float64(489.25925925925924)

# %%
sales_df = sales_df.head(10)

# %%
sales_df
# Out:
#    Sales  Units  Transactions  Gross Profits  Customers Promotions(Yes/No)  \
# 0  701.0     49            38             37         99                Yes
# 1  807.0     73            14             81         81                Yes
# 2  743.0     23            75             38         40                Yes
# 3  347.0     85            82             74         32                Yes
# 4  275.0    100            10             83         43                Yes
# 5  397.0     35            38             68         28                 No
# 6  744.0     14            64             41         73                Yes
# 7  519.0     47            78             17         11                 No
# 8  822.0     11            33             87         89                 No
# 9  138.0     46            97             14         61                 No
#
#     Location   Days
# 0  Bangalore  Day 1
# 1  Bangalore  Day 2
# 2  Bangalore  Day 3
# 3  Bangalore  Day 4
# 4  Bangalore  Day 5
# ...

# %%
sales_df['Sales']
# Out:
# 0    701.0
# 1    807.0
# 2    743.0
# 3    347.0
# 4    275.0
# 5    397.0
# 6    744.0
# 7    519.0
# 8    822.0
# 9    138.0
# Name: Sales, dtype: float64

# %%
sales_df['Sales'].cumsum()
# Out:
# 0     701.0
# 1    1508.0
# 2    2251.0
# 3    2598.0
# 4    2873.0
# 5    3270.0
# 6    4014.0
# 7    4533.0
# 8    5355.0
# 9    5493.0
# Name: Sales, dtype: float64

# %%
sales_df['Sales'].cumprod()
# Out:
# 0    7.010000e+02
# 1    5.657070e+05
# 2    4.203203e+08
# 3    1.458511e+11
# 4    4.010906e+13
# 5    1.592330e+16
# 6    1.184693e+19
# 7    6.148559e+21
# 8    5.054115e+24
# 9    6.974679e+26
# Name: Sales, dtype: float64

# %%
sales_df['Sales'].median()
# Out:
# np.float64(610.0)

# %%
sales_df.shape ### return rows and columns
# Out:
# (10, 8)

# %%
sales_df.dtypes
# Out:
# Sales                 float64
# Units                   int64
# Transactions            int64
# Gross Profits           int64
# Customers               int64
# Promotions(Yes/No)        str
# Location                  str
# Days                      str
# dtype: object
