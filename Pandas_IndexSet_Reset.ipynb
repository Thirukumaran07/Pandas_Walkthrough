# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
df = sns.load_dataset("titanic")

# %%
df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
df.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
df.set_index('alone').head()
# Out:
#        survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# alone
# False         0       3    male  22.0      1      0   7.2500        S  Third
# False         1       1  female  38.0      1      0  71.2833        C  First
# True          1       3  female  26.0      0      0   7.9250        S  Third
# False         1       1  female  35.0      1      0  53.1000        S  First
# True          0       3    male  35.0      0      0   8.0500        S  Third
#
#          who  adult_male deck  embark_town alive
# alone
# False    man        True  NaN  Southampton    no
# False  woman       False    C    Cherbourg   yes
# True   woman       False  NaN  Southampton   yes
# False  woman       False    C  Southampton   yes
# True     man        True  NaN  Southampton    no

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.set_index('alone',inplace=True)

# %%
df.head()
# Out:
#        survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# alone
# False         0       3    male  22.0      1      0   7.2500        S  Third
# False         1       1  female  38.0      1      0  71.2833        C  First
# True          1       3  female  26.0      0      0   7.9250        S  Third
# False         1       1  female  35.0      1      0  53.1000        S  First
# True          0       3    male  35.0      0      0   8.0500        S  Third
#
#          who  adult_male deck  embark_town alive
# alone
# False    man        True  NaN  Southampton    no
# False  woman       False    C    Cherbourg   yes
# True   woman       False  NaN  Southampton   yes
# False  woman       False    C  Southampton   yes
# True     man        True  NaN  Southampton    no

# %%
df.reset_index().head()
# Out:
#    alone  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0  False         0       3    male  22.0      1      0   7.2500        S
# 1  False         1       1  female  38.0      1      0  71.2833        C
# 2   True         1       3  female  26.0      0      0   7.9250        S
# 3  False         1       1  female  35.0      1      0  53.1000        S
# 4   True         0       3    male  35.0      0      0   8.0500        S
#
#    class    who  adult_male deck  embark_town alive
# 0  Third    man        True  NaN  Southampton    no
# 1  First  woman       False    C    Cherbourg   yes
# 2  Third  woman       False  NaN  Southampton   yes
# 3  First  woman       False    C  Southampton   yes
# 4  Third    man        True  NaN  Southampton    no

# %%
df.head()
# Out:
#        survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# alone
# False         0       3    male  22.0      1      0   7.2500        S  Third
# False         1       1  female  38.0      1      0  71.2833        C  First
# True          1       3  female  26.0      0      0   7.9250        S  Third
# False         1       1  female  35.0      1      0  53.1000        S  First
# True          0       3    male  35.0      0      0   8.0500        S  Third
#
#          who  adult_male deck  embark_town alive
# alone
# False    man        True  NaN  Southampton    no
# False  woman       False    C    Cherbourg   yes
# True   woman       False  NaN  Southampton   yes
# False  woman       False    C  Southampton   yes
# True     man        True  NaN  Southampton    no

# %%
df.shape
# Out:
# (891, 14)
