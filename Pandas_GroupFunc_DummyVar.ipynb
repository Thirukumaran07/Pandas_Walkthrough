# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
df=sns.load_dataset("titanic")

# %%
df['who'].unique()
# Out:
# <ArrowStringArray>
# ['man', 'woman', 'child']
# Length: 3, dtype: str

# %%
pd.get_dummies(df['who']).head()
# Out:
#    child    man  woman
# 0  False   True  False
# 1  False  False   True
# 2  False  False   True
# 3  False  False   True
# 4  False   True  False

# %%
### groupy functions

# %%
df=sns.load_dataset("mpg")

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
### based on single col

# %%
df.groupby('origin').sum()
# Out:
#            mpg  cylinders  displacement  horsepower  weight  acceleration  \
# origin
# europe  1952.4        291        7640.0      5478.0  169631        1175.1
# japan   2405.6        324        8114.0      6307.0  175477        1277.6
# usa     5000.8       1556       61229.5     29167.0  837121        3743.4
#
#         model_year                                               name
# origin
# europe        5307  volkswagen 1131 deluxe sedanpeugeot 504audi 10...
# japan         6118  toyota corona mark iidatsun pl510datsun pl510t...
# usa          18827  chevrolet chevelle malibubuick skylark 320plym...

# %%
df[df['origin']=='europe'].shape
# Out:
# (70, 9)

# %%
den = 70

# %%
num = df[df['origin']=='europe']['mpg'].sum()

# %%
num/den
# Out:
# np.float64(27.89142857142857)

# %%
df.groupby(['origin','model_year']).sum()
# Out:
#                      mpg  cylinders  displacement  horsepower  weight  \
# origin model_year
# europe 70          126.0         20         539.0       431.0   11546
#        71          115.0         16         380.0       296.0    8096
#        72          110.0         20         555.0       398.0   12866
#        73          168.0         28         735.0       573.0   16350
#        74          162.0         24         559.0       445.0   12836
#        75          147.0         24         657.0       537.0   15427
#        76          194.0         34         929.0       701.0   20888
#        77          117.0         16         394.0       324.0    8555
#        78          149.7         29         757.0       595.0   16150
#        79          121.8         17         504.0       288.0   10775
#        80          335.6         37         938.0       534.0   21132
#        81          126.3         18         491.0       230.0   10900
# ...
